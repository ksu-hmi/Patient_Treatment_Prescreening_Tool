# %%
import pandas as pd
import numpy as np

medicine = pd.read_csv("C:\FALL SEMESTER 2022\Healthcare Info (Dominic Thomas)\medicine new.csv")

# %%
medicine
# Out:
#      Medicine_ID                 Medicine_Name Medicine_Description  \
# 0         1001.0              Ibuprofen 200 mg  Pain/Fever Reliever
# 1         1002.0           Acetaminophen 325mg  Pain/Fever Reliever
# 2         1003.0  Pediatric Acetaminophen 2.6g  Pain/Fever Reliever
# 3         1004.0               Naxproxen 200mg  Pain/Fever Reliever
# 4         1005.0              Aspirin 81 mg EC  Pain/Fever Reliever
# ..           ...                           ...                  ...
# 105          NaN                           NaN                  NaN
# 106          NaN                           NaN                  NaN
# 107          NaN                           NaN                  NaN
# 108          NaN                           NaN                  NaN
# 109          NaN                           NaN                  NaN
#
#      Unnamed: 3
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 105         NaN
# ...

# %%
medicine.head()
# Out:
#    Medicine_ID                 Medicine_Name Medicine_Description  Unnamed: 3
# 0       1001.0              Ibuprofen 200 mg  Pain/Fever Reliever         NaN
# 1       1002.0           Acetaminophen 325mg  Pain/Fever Reliever         NaN
# 2       1003.0  Pediatric Acetaminophen 2.6g  Pain/Fever Reliever         NaN
# 3       1004.0               Naxproxen 200mg  Pain/Fever Reliever         NaN
# 4       1005.0              Aspirin 81 mg EC  Pain/Fever Reliever         NaN
